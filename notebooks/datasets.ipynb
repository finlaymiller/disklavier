# %%
import os
import shutil
from rich.progress import track

# %%
def copy_every_third_file(source_dir, destination_dir):
    """
    Copies every third file from the source directory to the destination directory.

    :param source_dir: Path to the source directory
    :param destination_dir: Path to the destination directory
    """
    # Get a list of files in the source directory
    files = [
        f for f in os.listdir(source_dir) if os.path.isfile(os.path.join(source_dir, f))
    ]

    # Ensure the destination directory exists, create if not
    if not os.path.exists(destination_dir):
        os.makedirs(destination_dir)

    # Copy every third file
    for i, file in track(enumerate(files)):
        if i % 3 == 0:
            shutil.copy(os.path.join(source_dir, file), destination_dir)


# Example usage
source_dir = "../inputs/all"
destination_dir = "../inputs/one third"
copy_every_third_file(source_dir, destination_dir)
# Out:
# /Users/finlay/Documents/Programming/disklavier/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning:
# install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
import torch
import numpy as np

test_arr_size = (49000, 20)
filename = "tmp/49k20.npy"
t = torch.rand(test_arr_size)
np.save(filename, t.numpy())
arr = np.load(filename)

print(arr)
# Out:
# [[0.52243596 0.4076234  0.7374051  ... 0.82006884 0.5427777  0.97510105]
#  [0.12476951 0.69680524 0.01635784 ... 0.649835   0.28218532 0.8491808 ]
#  [0.27044326 0.19974446 0.97836226 ... 0.9859257  0.352395   0.6075037 ]
#  ...
#  [0.53693116 0.69925314 0.41830122 ... 0.5209224  0.6024851  0.2358107 ]
#  [0.09096557 0.24886006 0.06690371 ... 0.8135111  0.05231154 0.9036798 ]
#  [0.90812826 0.31012738 0.7655051  ... 0.8500044  0.13340473 0.75846946]]
